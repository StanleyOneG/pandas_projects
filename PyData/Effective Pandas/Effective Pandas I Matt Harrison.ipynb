# %%
# %matplotlib inline
from IPython.display import display
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '1.3.4'

# %%
pd.options.display.min_rows = 20

# %%
autos = pd.read_csv('https://github.com/mattharrison/datasets/raw/master/data/vehicles.csv.zip')
# Out:
# C:\Users\Goncharuk.SM\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (68,70,71,72,73,74,76,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
autos
# Out:
#        barrels08  barrelsA08  charge120  charge240  city08  city08U  cityA08  \
# 0      15.695714         0.0        0.0        0.0      19      0.0        0
# 1      29.964545         0.0        0.0        0.0       9      0.0        0
# 2      12.207778         0.0        0.0        0.0      23      0.0        0
# 3      29.964545         0.0        0.0        0.0      10      0.0        0
# 4      17.347895         0.0        0.0        0.0      17      0.0        0
# 5      14.982273         0.0        0.0        0.0      21      0.0        0
# 6      13.184400         0.0        0.0        0.0      22      0.0        0
# 7      13.733750         0.0        0.0        0.0      23      0.0        0
# 8      12.677308         0.0        0.0        0.0      23      0.0        0
# 9      13.184400         0.0        0.0        0.0      23      0.0        0
# ...          ...         ...        ...        ...     ...      ...      ...
# 41134  16.480500         0.0        0.0        0.0      18      0.0        0
# 41135  12.677308         0.0        0.0        0.0      23      0.0        0
# 41136  13.733750         0.0        0.0        0.0      21      0.0        0
# 41137  11.771786         0.0        0.0        0.0      24      0.0        0
# 41138  13.184400         0.0        0.0        0.0      21      0.0        0
# 41139  14.982273         0.0        0.0        0.0      19      0.0        0
# 41140  14.330870         0.0        0.0        0.0      20      0.0        0
# 41141  15.695714         0.0        0.0        0.0      18      0.0        0
# 41142  15.695714         0.0        0.0        0.0      18      0.0        0
# 41143  18.311667         0.0        0.0        0.0      16      0.0        0
#
#        cityA08U  cityCD  cityE  ...  mfrCode  c240Dscr  charge240b  c240bDscr  \
# 0           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 1           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 2           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 3           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 4           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 5           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 6           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 7           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 8           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 9           0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# ...         ...     ...    ...  ...      ...       ...         ...        ...
# 41134       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 41135       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 41136       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 41137       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 41138       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 41139       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 41140       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 41141       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 41142       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
# 41143       0.0     0.0    0.0  ...      NaN       NaN         0.0        NaN
#
#                           createdOn                    modifiedOn  startStop  \
# 0      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 1      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 2      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 3      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 4      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 5      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 6      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 7      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 8      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 9      Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# ...                             ...                           ...        ...
# 41134  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 41135  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 41136  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 41137  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 41138  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 41139  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 41140  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 41141  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 41142  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
# 41143  Tue Jan 01 00:00:00 EST 2013  Tue Jan 01 00:00:00 EST 2013        NaN
#
#        phevCity  phevHwy  phevComb
# 0             0        0         0
# 1             0        0         0
# 2             0        0         0
# 3             0        0         0
# 4             0        0         0
# 5             0        0         0
# 6             0        0         0
# 7             0        0         0
# 8             0        0         0
# 9             0        0         0
# ...         ...      ...       ...
# 41134         0        0         0
# 41135         0        0         0
# 41136         0        0         0
# 41137         0        0         0
# 41138         0        0         0
# 41139         0        0         0
# 41140         0        0         0
# 41141         0        0         0
# 41142         0        0         0
# 41143         0        0         0
#
# [41144 rows x 83 columns]

# %%
autos.columns
# Out:
# Index(['barrels08', 'barrelsA08', 'charge120', 'charge240', 'city08',
#        'city08U', 'cityA08', 'cityA08U', 'cityCD', 'cityE', 'cityUF', 'co2',
#        'co2A', 'co2TailpipeAGpm', 'co2TailpipeGpm', 'comb08', 'comb08U',
#        'combA08', 'combA08U', 'combE', 'combinedCD', 'combinedUF', 'cylinders',
#        'displ', 'drive', 'engId', 'eng_dscr', 'feScore', 'fuelCost08',
#        'fuelCostA08', 'fuelType', 'fuelType1', 'ghgScore', 'ghgScoreA',
#        'highway08', 'highway08U', 'highwayA08', 'highwayA08U', 'highwayCD',
#        'highwayE', 'highwayUF', 'hlv', 'hpv', 'id', 'lv2', 'lv4', 'make',
#        'model', 'mpgData', 'phevBlended', 'pv2', 'pv4', 'range', 'rangeCity',
#        'rangeCityA', 'rangeHwy', 'rangeHwyA', 'trany', 'UCity', 'UCityA',
#        'UHighway', 'UHighwayA', 'VClass', 'year', 'youSaveSpend', 'guzzler',
#        'trans_dscr', 'tCharger', 'sCharger', 'atvType', 'fuelType2', 'rangeA',
#        'evMotor', 'mfrCode', 'c240Dscr', 'charge240b', 'c240bDscr',
#        'createdOn', 'modifiedOn', 'startStop', 'phevCity', 'phevHwy',
#        'phevComb'],
#       dtype='object')

# %%
cols = ['city08', 'comb08', 'highway08', 'cylinders', 'displ', 'drive', 'eng_dscr', 
        'fuelCost08', 'make', 'model', 'trany', 'range', 'createdOn', 'year']

# %%
autos[cols].dtypes
# Out:
# city08          int64
# comb08          int64
# highway08       int64
# cylinders     float64
# displ         float64
# drive          object
# eng_dscr       object
# fuelCost08      int64
# make           object
# model          object
# trany          object
# range           int64
# createdOn      object
# year            int64
# dtype: object

# %%
autos[cols].memory_usage(deep=True)
# Out:
# Index             128
# city08         329152
# comb08         329152
# highway08      329152
# cylinders      329152
# displ          329152
# drive         3028369
# eng_dscr      2135693
# fuelCost08     329152
# make          2606267
# model         2813134
# trany         2933276
# range          329152
# createdOn     3497240
# year           329152
# dtype: int64

# %%
autos[cols].memory_usage(deep=True).sum()
# Out:
# 19647323

# %% [markdown]
# # Ints

# %%
autos[cols].select_dtypes(int).describe()
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  41144.000000  41144.000000  41144.000000  41144.000000  41144.000000
# mean      18.369045     20.616396     24.504667   2362.335942      0.793506
# std        7.905886      7.674535      7.730364    654.981925     13.041592
# min        6.000000      7.000000      9.000000    500.000000      0.000000
# 25%       15.000000     17.000000     20.000000   1900.000000      0.000000
# 50%       17.000000     20.000000     24.000000   2350.000000      0.000000
# 75%       20.000000     23.000000     28.000000   2700.000000      0.000000
# max      150.000000    136.000000    124.000000   7400.000000    370.000000
#
#                year
# count  41144.000000
# mean    2001.535266
# std       11.142414
# min     1984.000000
# 25%     1991.000000
# 50%     2002.000000
# 75%     2011.000000
# max     2020.000000

# %%
# chaining
(autos
 [cols]
 .select_dtypes(int)
 .describe()
)
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  41144.000000  41144.000000  41144.000000  41144.000000  41144.000000
# mean      18.369045     20.616396     24.504667   2362.335942      0.793506
# std        7.905886      7.674535      7.730364    654.981925     13.041592
# min        6.000000      7.000000      9.000000    500.000000      0.000000
# 25%       15.000000     17.000000     20.000000   1900.000000      0.000000
# 50%       17.000000     20.000000     24.000000   2350.000000      0.000000
# 75%       20.000000     23.000000     28.000000   2700.000000      0.000000
# max      150.000000    136.000000    124.000000   7400.000000    370.000000
#
#                year
# count  41144.000000
# mean    2001.535266
# std       11.142414
# min     1984.000000
# 25%     1991.000000
# 50%     2002.000000
# 75%     2011.000000
# max     2020.000000

# %%
# can comb08 be an int8?
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
np.iinfo(np.int16)
# Out:
# iinfo(min=-32768, max=32767, dtype=int16)

# %%
# chaining 
(autos
 [cols]
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16'})
 .select_dtypes([int, 'int8'])
 .describe()
)
# Out:
#           highway08    fuelCost08         range          year
# count  41144.000000  41144.000000  41144.000000  41144.000000
# mean      24.504667   2362.335942      0.793506   2001.535266
# std        7.730364    654.981925     13.041592     11.142414
# min        9.000000    500.000000      0.000000   1984.000000
# 25%       20.000000   1900.000000      0.000000   1991.000000
# 50%       24.000000   2350.000000      0.000000   2002.000000
# 75%       28.000000   2700.000000      0.000000   2011.000000
# max      124.000000   7400.000000    370.000000   2020.000000

# %%
# chaining 
# use 'integer' so see all int-like columns
(autos
 [cols]
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
         'range': 'int16', 'year': 'int16'})
 .select_dtypes(['integer'])
 .describe()
)
# Out:
#              city08        comb08     highway08    fuelCost08         range  \
# count  41144.000000  41144.000000  41144.000000  41144.000000  41144.000000
# mean      18.369045     20.616396     24.504667   2362.335942      0.793506
# std        7.905886      7.674535      7.730364    654.981925     13.041592
# min        6.000000      7.000000      9.000000    500.000000      0.000000
# 25%       15.000000     17.000000     20.000000   1900.000000      0.000000
# 50%       17.000000     20.000000     24.000000   2350.000000      0.000000
# 75%       20.000000     23.000000     28.000000   2700.000000      0.000000
# max      150.000000    136.000000    124.000000   7400.000000    370.000000
#
#                year
# count  41144.000000
# mean    2001.535266
# std       11.142414
# min     1984.000000
# 25%     1991.000000
# 50%     2002.000000
# 75%     2011.000000
# max     2020.000000

# %%
(autos
 [cols]
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
         'range': 'int16', 'year': 'int16'})
 .memory_usage(deep=True)
 .sum()
)
# Out:
# 18124995

# %% [markdown]
# # Floats

# %%
(autos
 [cols]
 .select_dtypes('float')
)
# Out:
#        cylinders  displ
# 0            4.0    2.0
# 1           12.0    4.9
# 2            4.0    2.2
# 3            8.0    5.2
# 4            4.0    2.2
# 5            4.0    1.8
# 6            4.0    1.8
# 7            4.0    1.6
# 8            4.0    1.6
# 9            4.0    1.8
# ...          ...    ...
# 41134        4.0    2.1
# 41135        4.0    1.9
# 41136        4.0    1.9
# 41137        4.0    1.9
# 41138        4.0    1.9
# 41139        4.0    2.2
# 41140        4.0    2.2
# 41141        4.0    2.2
# 41142        4.0    2.2
# 41143        4.0    2.2
#
# [41144 rows x 2 columns]

# %%
# cylinders lools int-like
autos.cylinders.describe()
# Out:
# count    40938.000000
# mean         5.717084
# std          1.755517
# min          2.000000
# 25%          4.000000
# 50%          6.000000
# 75%          6.000000
# max         16.000000
# Name: cylinders, dtype: float64

# %%
# missing values
autos.cylinders.value_counts(dropna=False)
# Out:
# 4.0     15938
# 6.0     14284
# 8.0      8801
# 5.0       771
# 12.0      626
# 3.0       279
# NaN       206
# 10.0      170
# 2.0        59
# 16.0       10
# Name: cylinders, dtype: int64

# %%
# what are they missing?
(autos
 [cols]
 .query('cylinders.isna()')
)
# Out:
#        city08  comb08  highway08  cylinders  displ              drive  \
# 7138       81      85         91        NaN    NaN                NaN
# 7139       81      72         64        NaN    NaN      2-Wheel Drive
# 8143       81      72         64        NaN    NaN      2-Wheel Drive
# 8144       74      65         58        NaN    NaN                NaN
# 8146       45      39         33        NaN    NaN      2-Wheel Drive
# 8147       84      75         66        NaN    NaN                NaN
# 9212       87      78         69        NaN    NaN      2-Wheel Drive
# 9213       45      39         33        NaN    NaN      2-Wheel Drive
# 10329      87      78         69        NaN    NaN      2-Wheel Drive
# 21413      22      24         28        NaN    NaN      4-Wheel Drive
# ...       ...     ...        ...        ...    ...                ...
# 34407      73      72         71        NaN    NaN  Front-Wheel Drive
# 34408     118     108         97        NaN    NaN  Front-Wheel Drive
# 34409     114     104         94        NaN    NaN  Front-Wheel Drive
# 34538      74      74         73        NaN    NaN    All-Wheel Drive
# 34561      80      76         72        NaN    NaN      4-Wheel Drive
# 34563     138     131        124        NaN    NaN   Rear-Wheel Drive
# 34564     140     133        124        NaN    NaN   Rear-Wheel Drive
# 34565     115     111        107        NaN    NaN    All-Wheel Drive
# 34566     104     104        104        NaN    NaN    All-Wheel Drive
# 34567      98      97         96        NaN    NaN    All-Wheel Drive
#
#       eng_dscr  fuelCost08    make                               model  \
# 7138       NaN         800  Nissan                            Altra EV
# 7139       NaN         900  Toyota                             RAV4 EV
# 8143       NaN         900  Toyota                             RAV4 EV
# 8144       NaN        1000    Ford                               Th!nk
# 8146       NaN        1700    Ford              Explorer USPS Electric
# 8147       NaN         900  Nissan                          Hyper-Mini
# 9212       NaN         850  Toyota                             RAV4 EV
# 9213       NaN        1700    Ford              Explorer USPS Electric
# 10329      NaN         850  Toyota                             RAV4 EV
# 21413      NaN        1750  Subaru                            RX Turbo
# ...        ...         ...     ...                                 ...
# 34407      NaN         900     BYD                                  e6
# 34408      NaN         600  Nissan        Leaf (62 kW-hr battery pack)
# 34409      NaN         650  Nissan  Leaf SV/SL (62 kW-hr battery pack)
# 34538      NaN         900    Audi                              e-tron
# 34561      NaN         850  Jaguar                              I-Pace
# 34563      NaN         500   Tesla              Model 3 Standard Range
# 34564      NaN         500   Tesla         Model 3 Standard Range Plus
# 34565      NaN         600   Tesla                  Model S Long Range
# 34566      NaN         650   Tesla    Model S Performance (19" Wheels)
# 34567      NaN         700   Tesla    Model S Performance (21" Wheels)
#
#                 trany  range                     createdOn  year
# 7138              NaN     90  Tue Jan 01 00:00:00 EST 2013  2000
# 7139              NaN     88  Tue Jan 01 00:00:00 EST 2013  2000
# 8143              NaN     88  Tue Jan 01 00:00:00 EST 2013  2001
# 8144              NaN     29  Tue Jan 01 00:00:00 EST 2013  2001
# 8146              NaN     38  Tue Jan 01 00:00:00 EST 2013  2001
# 8147              NaN     33  Tue Jan 01 00:00:00 EST 2013  2001
# 9212              NaN     95  Tue Jan 01 00:00:00 EST 2013  2002
# 9213              NaN     38  Tue Jan 01 00:00:00 EST 2013  2002
# 10329             NaN     95  Tue Jan 01 00:00:00 EST 2013  2003
# 21413    Manual 5-spd      0  Tue Jan 01 00:00:00 EST 2013  1985
# ...               ...    ...                           ...   ...
# 34407  Automatic (A1)    187  Wed Mar 13 00:00:00 EDT 2019  2019
# 34408  Automatic (A1)    226  Wed Mar 13 00:00:00 EDT 2019  2019
# 34409  Automatic (A1)    215  Wed Mar 13 00:00:00 EDT 2019  2019
# 34538  Automatic (A1)    204  Tue Apr 16 00:00:00 EDT 2019  2019
# 34561  Automatic (A1)    234  Thu May 02 00:00:00 EDT 2019  2020
# 34563  Automatic (A1)    220  Thu May 02 00:00:00 EDT 2019  2019
# 34564  Automatic (A1)    240  Thu May 02 00:00:00 EDT 2019  2019
# 34565  Automatic (A1)    370  Thu May 02 00:00:00 EDT 2019  2019
# 34566  Automatic (A1)    345  Thu May 02 00:00:00 EDT 2019  2019
# 34567  Automatic (A1)    325  Thu May 02 00:00:00 EDT 2019  2019
#
# [206 rows x 14 columns]

# %%
# add cylinders and displ columns
(autos
 [cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
        displ=autos.displ.fillna(0))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
         'range': 'int16', 'year': 'int16'})
 .describe()
)
# Out:
#              city08        comb08     highway08     cylinders         displ  \
# count  41144.000000  41144.000000  41144.000000  41144.000000  41144.000000
# mean      18.369045     20.616396     24.504667      5.688460      3.277904
# std        7.905886      7.674535      7.730364      1.797009      1.373415
# min        6.000000      7.000000      9.000000      0.000000      0.000000
# 25%       15.000000     17.000000     20.000000      4.000000      2.200000
# 50%       17.000000     20.000000     24.000000      6.000000      3.000000
# 75%       20.000000     23.000000     28.000000      6.000000      4.300000
# max      150.000000    136.000000    124.000000     16.000000      8.400000
#
#          fuelCost08         range          year
# count  41144.000000  41144.000000  41144.000000
# mean    2362.335942      0.793506   2001.535266
# std      654.981925     13.041592     11.142414
# min      500.000000      0.000000   1984.000000
# 25%     1900.000000      0.000000   1991.000000
# 50%     2350.000000      0.000000   2002.000000
# 75%     2700.000000      0.000000   2011.000000
# max     7400.000000    370.000000   2020.000000

# %%
autos[cols].describe()
# Out:
#              city08        comb08     highway08     cylinders         displ  \
# count  41144.000000  41144.000000  41144.000000  40938.000000  40940.000000
# mean      18.369045     20.616396     24.504667      5.717084      3.294238
# std        7.905886      7.674535      7.730364      1.755517      1.357151
# min        6.000000      7.000000      9.000000      2.000000      0.000000
# 25%       15.000000     17.000000     20.000000      4.000000      2.200000
# 50%       17.000000     20.000000     24.000000      6.000000      3.000000
# 75%       20.000000     23.000000     28.000000      6.000000      4.300000
# max      150.000000    136.000000    124.000000     16.000000      8.400000
#
#          fuelCost08         range          year
# count  41144.000000  41144.000000  41144.000000
# mean    2362.335942      0.793506   2001.535266
# std      654.981925     13.041592     11.142414
# min      500.000000      0.000000   1984.000000
# 25%     1900.000000      0.000000   1991.000000
# 50%     2350.000000      0.000000   2002.000000
# 75%     2700.000000      0.000000   2011.000000
# max     7400.000000    370.000000   2020.000000

# %%
# use this to inspect float size
np.finfo(np.float16)
# Out:
# finfo(resolution=0.001, min=-6.55040e+04, max=6.55040e+04, dtype=float16)

# %%
# chaining - convert displ to float16
(autos
 [cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
        displ=autos.displ.fillna(0).astype('float16'))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
         'range': 'int16', 'year': 'int16'})
)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# 5          21      22         24          4  1.799805
# 6          22      25         29          4  1.799805
# 7          23      24         26          4  1.599609
# 8          23      26         31          4  1.599609
# 9          23      25         30          4  1.799805
# ...       ...     ...        ...        ...       ...
# 41134      18      20         24          4  2.099609
# 41135      23      26         33          4  1.900391
# 41136      21      24         30          4  1.900391
# 41137      24      28         33          4  1.900391
# 41138      21      25         32          4  1.900391
# 41139      19      22         26          4  2.199219
# 41140      20      23         28          4  2.199219
# 41141      18      21         24          4  2.199219
# 41142      18      21         24          4  2.199219
# 41143      16      18         21          4  2.199219
#
#                             drive          eng_dscr  fuelCost08        make  \
# 0                Rear-Wheel Drive             (FFS)        2000  Alfa Romeo
# 1                Rear-Wheel Drive         (GUZZLER)        3850     Ferrari
# 2               Front-Wheel Drive             (FFS)        1550       Dodge
# 3                Rear-Wheel Drive               NaN        3850       Dodge
# 4      4-Wheel or All-Wheel Drive        (FFS,TRBO)        2700      Subaru
# 5               Front-Wheel Drive             (FFS)        1900      Subaru
# 6               Front-Wheel Drive             (FFS)        1700      Subaru
# 7               Front-Wheel Drive             (FFS)        1750      Toyota
# 8               Front-Wheel Drive             (FFS)        1600      Toyota
# 9               Front-Wheel Drive             (FFS)        1700      Toyota
# ...                           ...               ...         ...         ...
# 41134           Front-Wheel Drive             (FFS)        2100        Saab
# 41135           Front-Wheel Drive  (TBI)      (FFS)        1600      Saturn
# 41136           Front-Wheel Drive  (MFI)      (FFS)        1750      Saturn
# 41137           Front-Wheel Drive  (TBI)      (FFS)        1500      Saturn
# 41138           Front-Wheel Drive  (MFI)      (FFS)        1700      Saturn
# 41139           Front-Wheel Drive             (FFS)        1900      Subaru
# 41140           Front-Wheel Drive             (FFS)        1850      Subaru
# 41141  4-Wheel or All-Wheel Drive             (FFS)        2000      Subaru
# 41142  4-Wheel or All-Wheel Drive             (FFS)        2000      Subaru
# 41143  4-Wheel or All-Wheel Drive        (FFS,TRBO)        2900      Subaru
#
#                      model            trany  range  \
# 0       Spider Veloce 2000     Manual 5-spd      0
# 1               Testarossa     Manual 5-spd      0
# 2                  Charger     Manual 5-spd      0
# 3      B150/B250 Wagon 2WD  Automatic 3-spd      0
# 4         Legacy AWD Turbo     Manual 5-spd      0
# 5                   Loyale  Automatic 3-spd      0
# 6                   Loyale     Manual 5-spd      0
# 7                  Corolla  Automatic 3-spd      0
# 8                  Corolla     Manual 5-spd      0
# 9                  Corolla  Automatic 4-spd      0
# ...                    ...              ...    ...
# 41134                  900     Manual 5-spd      0
# 41135                   SL  Automatic 4-spd      0
# 41136                   SL  Automatic 4-spd      0
# 41137                   SL     Manual 5-spd      0
# 41138                   SL     Manual 5-spd      0
# 41139               Legacy  Automatic 4-spd      0
# 41140               Legacy     Manual 5-spd      0
# 41141           Legacy AWD  Automatic 4-spd      0
# 41142           Legacy AWD     Manual 5-spd      0
# 41143     Legacy AWD Turbo  Automatic 4-spd      0
#
#                           createdOn  year
# 0      Tue Jan 01 00:00:00 EST 2013  1985
# 1      Tue Jan 01 00:00:00 EST 2013  1985
# 2      Tue Jan 01 00:00:00 EST 2013  1985
# 3      Tue Jan 01 00:00:00 EST 2013  1985
# 4      Tue Jan 01 00:00:00 EST 2013  1993
# 5      Tue Jan 01 00:00:00 EST 2013  1993
# 6      Tue Jan 01 00:00:00 EST 2013  1993
# 7      Tue Jan 01 00:00:00 EST 2013  1993
# 8      Tue Jan 01 00:00:00 EST 2013  1993
# 9      Tue Jan 01 00:00:00 EST 2013  1993
# ...                             ...   ...
# 41134  Tue Jan 01 00:00:00 EST 2013  1993
# 41135  Tue Jan 01 00:00:00 EST 2013  1993
# 41136  Tue Jan 01 00:00:00 EST 2013  1993
# 41137  Tue Jan 01 00:00:00 EST 2013  1993
# 41138  Tue Jan 01 00:00:00 EST 2013  1993
# 41139  Tue Jan 01 00:00:00 EST 2013  1993
# 41140  Tue Jan 01 00:00:00 EST 2013  1993
# 41141  Tue Jan 01 00:00:00 EST 2013  1993
# 41142  Tue Jan 01 00:00:00 EST 2013  1993
# 41143  Tue Jan 01 00:00:00 EST 2013  1993
#
# [41144 rows x 14 columns]

# %%
# memory usage
(autos
 #[cols]
 .loc[:, cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
        displ=autos.displ.fillna(0).astype('float16'))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
         'range': 'int16', 'year': 'int16'})
 .memory_usage(deep=True)
 .sum()
)
# Out:
# 17590123

# %% [markdown]
# # Objects

# %%
(autos
 [cols]
 .select_dtypes(object)
)
# Out:
#                             drive          eng_dscr        make  \
# 0                Rear-Wheel Drive             (FFS)  Alfa Romeo
# 1                Rear-Wheel Drive         (GUZZLER)     Ferrari
# 2               Front-Wheel Drive             (FFS)       Dodge
# 3                Rear-Wheel Drive               NaN       Dodge
# 4      4-Wheel or All-Wheel Drive        (FFS,TRBO)      Subaru
# 5               Front-Wheel Drive             (FFS)      Subaru
# 6               Front-Wheel Drive             (FFS)      Subaru
# 7               Front-Wheel Drive             (FFS)      Toyota
# 8               Front-Wheel Drive             (FFS)      Toyota
# 9               Front-Wheel Drive             (FFS)      Toyota
# ...                           ...               ...         ...
# 41134           Front-Wheel Drive             (FFS)        Saab
# 41135           Front-Wheel Drive  (TBI)      (FFS)      Saturn
# 41136           Front-Wheel Drive  (MFI)      (FFS)      Saturn
# 41137           Front-Wheel Drive  (TBI)      (FFS)      Saturn
# 41138           Front-Wheel Drive  (MFI)      (FFS)      Saturn
# 41139           Front-Wheel Drive             (FFS)      Subaru
# 41140           Front-Wheel Drive             (FFS)      Subaru
# 41141  4-Wheel or All-Wheel Drive             (FFS)      Subaru
# 41142  4-Wheel or All-Wheel Drive             (FFS)      Subaru
# 41143  4-Wheel or All-Wheel Drive        (FFS,TRBO)      Subaru
#
#                      model            trany                     createdOn
# 0       Spider Veloce 2000     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 1               Testarossa     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 2                  Charger     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 3      B150/B250 Wagon 2WD  Automatic 3-spd  Tue Jan 01 00:00:00 EST 2013
# 4         Legacy AWD Turbo     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 5                   Loyale  Automatic 3-spd  Tue Jan 01 00:00:00 EST 2013
# 6                   Loyale     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 7                  Corolla  Automatic 3-spd  Tue Jan 01 00:00:00 EST 2013
# 8                  Corolla     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 9                  Corolla  Automatic 4-spd  Tue Jan 01 00:00:00 EST 2013
# ...                    ...              ...                           ...
# 41134                  900     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 41135                   SL  Automatic 4-spd  Tue Jan 01 00:00:00 EST 2013
# 41136                   SL  Automatic 4-spd  Tue Jan 01 00:00:00 EST 2013
# 41137                   SL     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 41138                   SL     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 41139               Legacy  Automatic 4-spd  Tue Jan 01 00:00:00 EST 2013
# 41140               Legacy     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 41141           Legacy AWD  Automatic 4-spd  Tue Jan 01 00:00:00 EST 2013
# 41142           Legacy AWD     Manual 5-spd  Tue Jan 01 00:00:00 EST 2013
# 41143     Legacy AWD Turbo  Automatic 4-spd  Tue Jan 01 00:00:00 EST 2013
#
# [41144 rows x 6 columns]

# %%
# looks categorical
autos.drive.value_counts(dropna=False)
# Out:
# Front-Wheel Drive             14236
# Rear-Wheel Drive              13831
# 4-Wheel or All-Wheel Drive     6648
# All-Wheel Drive                3015
# 4-Wheel Drive                  1460
# NaN                            1189
# 2-Wheel Drive                   507
# Part-time 4-Wheel Drive         258
# Name: drive, dtype: int64

# %%
# what are the values missing for drive?
(autos
 [cols]
 .query('drive.isna()')
)
# Out:
#        city08  comb08  highway08  cylinders  displ drive            eng_dscr  \
# 7138       81      85         91        NaN    NaN   NaN                 NaN
# 8144       74      65         58        NaN    NaN   NaN                 NaN
# 8147       84      75         66        NaN    NaN   NaN                 NaN
# 18217      18      21         25        4.0    2.0   NaN               (FFS)
# 18218      20      22         26        4.0    1.5   NaN               (FFS)
# 18219      13      15         20        8.0    5.7   NaN      (350 V8) (FFS)
# 18220      13      15         20        8.0    5.7   NaN      (350 V8) (FFS)
# 18221      15      17         20        6.0    3.0   NaN          (FFS,TRBO)
# 18222      16      18         20        6.0    3.0   NaN               (FFS)
# 18223      16      18         22        6.0    3.0   NaN          (FFS,TRBO)
# ...       ...     ...        ...        ...    ...   ...                 ...
# 20063      13      15         19        8.0    5.0   NaN      (FFS) CA model
# 20064      13      15         20        8.0    5.0   NaN  (GM-OLDS) CA model
# 20065      14      16         19        8.0    5.0   NaN  (GM-CHEV) CA model
# 20387      14      14         15        4.0    2.4   NaN      (FFS) CA model
# 21129      14      16         21        8.0    3.5   NaN  GUZZLER  FFS,TURBO
# 23029      79      85         94        NaN    NaN   NaN           Lead Acid
# 23030      35      37         39        NaN    NaN   NaN                NiMH
# 23032      49      48         46        NaN    NaN   NaN                 NaN
# 23037      49      48         46        NaN    NaN   NaN                 NaN
# 23040     102      98         94        NaN    NaN   NaN                 NaN
#
#        fuelCost08        make                 model            trany  range  \
# 7138          800      Nissan              Altra EV              NaN     90
# 8144         1000        Ford                 Th!nk              NaN     29
# 8147          900      Nissan            Hyper-Mini              NaN     33
# 18217        2000  Alfa Romeo    Spider Veloce 2000     Manual 5-spd      0
# 18218        1900     Bertone                  X1/9     Manual 5-spd      0
# 18219        2800   Chevrolet              Corvette  Automatic 4-spd      0
# 18220        2800   Chevrolet              Corvette     Manual 4-spd      0
# 18221        2500      Nissan                 300ZX  Automatic 4-spd      0
# 18222        2350      Nissan                 300ZX  Automatic 4-spd      0
# 18223        2350      Nissan                 300ZX     Manual 5-spd      0
# ...           ...         ...                   ...              ...    ...
# 20063        2800     Mercury   Grand Marquis Wagon  Automatic 4-spd      0
# 20064        2800  Oldsmobile  Custom Cruiser Wagon  Automatic 4-spd      0
# 20065        2650     Pontiac      Parisienne Wagon  Automatic 4-spd      0
# 20387        3000      Nissan    Pickup Cab Chassis     Manual 5-spd      0
# 21129        3250       Lotus             Esprit V8     Manual 5-spd      0
# 23029         800         GMC                   EV1   Automatic (A1)     55
# 23030        1750         GMC                   EV1   Automatic (A1)    105
# 23032        1400       Honda               EV Plus   Automatic (A1)     81
# 23037        1400       Honda               EV Plus   Automatic (A1)     81
# 23040         650        MINI                 MiniE   Automatic (A1)    100
#
#                           createdOn  year
# 7138   Tue Jan 01 00:00:00 EST 2013  2000
# 8144   Tue Jan 01 00:00:00 EST 2013  2001
# 8147   Tue Jan 01 00:00:00 EST 2013  2001
# 18217  Tue Jan 01 00:00:00 EST 2013  1984
# 18218  Tue Jan 01 00:00:00 EST 2013  1984
# 18219  Tue Jan 01 00:00:00 EST 2013  1984
# 18220  Tue Jan 01 00:00:00 EST 2013  1984
# 18221  Tue Jan 01 00:00:00 EST 2013  1984
# 18222  Tue Jan 01 00:00:00 EST 2013  1984
# 18223  Tue Jan 01 00:00:00 EST 2013  1984
# ...                             ...   ...
# 20063  Tue Jan 01 00:00:00 EST 2013  1984
# 20064  Tue Jan 01 00:00:00 EST 2013  1984
# 20065  Tue Jan 01 00:00:00 EST 2013  1984
# 20387  Tue Jan 01 00:00:00 EST 2013  1984
# 21129  Tue Jan 01 00:00:00 EST 2013  2002
# 23029  Tue Jan 01 00:00:00 EST 2013  1999
# 23030  Tue Jan 01 00:00:00 EST 2013  1999
# 23032  Tue Jan 01 00:00:00 EST 2013  1999
# 23037  Tue Jan 01 00:00:00 EST 2013  1998
# 23040  Tue Jan 01 00:00:00 EST 2013  2008
#
# [1189 rows x 14 columns]

# %%
(autos
[cols]
.groupby('year')
.drive
.nunique())
# Out:
# year
# 1984    3
# 1985    4
# 1986    4
# 1987    3
# 1988    3
# 1989    3
# 1990    3
# 1991    3
# 1992    3
# 1993    3
# 1994    3
# 1995    4
# 1996    3
# 1997    4
# 1998    4
# 1999    4
# 2000    4
# 2001    4
# 2002    4
# 2003    4
# 2004    4
# 2005    4
# 2006    4
# 2007    4
# 2008    3
# 2009    4
# 2010    6
# 2011    5
# 2012    5
# 2013    5
# 2014    5
# 2015    5
# 2016    5
# 2017    5
# 2018    5
# 2019    5
# 2020    5
# Name: drive, dtype: int64

# %%
# drive and make (in .astype) to category
(autos
[cols]
.assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
        displ=autos.displ.fillna(0).astype('float16'), 
       drive=autos.drive.fillna('Other').astype('category'))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
         'range': 'int16', 'year': 'int16', 'make': 'category'})
 .memory_usage(deep=True)
 .sum()
)
# Out:
# 12093275

# %%
# inspect trany
# looks like it has two pieces of information embedded in column
(autos.trany.value_counts(dropna=False))
# Out:
# Automatic 4-spd                     11047
# Manual 5-spd                         8361
# Automatic 3-spd                      3151
# Automatic (S6)                       3106
# Manual 6-spd                         2757
# Automatic 5-spd                      2203
# Automatic (S8)                       1665
# Automatic 6-spd                      1619
# Manual 4-spd                         1483
# Automatic (S5)                        833
# Automatic (variable gear ratios)      826
# Automatic 7-spd                       724
# Automatic 8-spd                       433
# Automatic (AM-S7)                     424
# Automatic (S7)                        327
# Automatic 9-spd                       293
# Automatic (AM7)                       245
# Automatic (S4)                        233
# Automatic (AV-S6)                     208
# Automatic (A1)                        201
# Automatic (AM6)                       151
# Automatic (AV-S7)                     139
# Automatic (S10)                       124
# Automatic (AM-S6)                     116
# Manual 7-spd                          114
# Automatic (S9)                         86
# Manual 3-spd                           77
# Automatic (AM-S8)                      60
# Automatic (AV-S8)                      47
# Automatic 10-spd                       25
# Manual 4-spd Doubled                   17
# Automatic (AM5)                        14
# NaN                                    11
# Automatic (AV-S10)                     11
# Automatic (AM8)                         6
# Automatic (AM-S9)                       3
# Automatic (L3)                          2
# Automatic (L4)                          2
# Name: trany, dtype: int64

# %%
# add automatic, speed from trany, then drop trany
(autos
 [cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0).astype('float16'),\
         drive=autos.drive.fillna('Other').astype('category'),
         automatic=autos.trany.str.contains('Auto'),
         speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
         'range': 'int16', 'year': 'int16', 'make': 'category'})
 .drop(columns=['trany'])
 .memory_usage(deep=True)
 .sum()
)
# Out:
# 10631047

# %% [markdown]
# # Dates

# %%
# Add CreatedOn
(autos
 [cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0).astype('float16'),\
         drive=autos.drive.fillna('Other').astype('category'),
         automatic=autos.trany.str.contains('Auto'),
         speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'),
         createdOn=pd.to_datetime(autos.createdOn).dt.tz_localize('Europe/Moscow'))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
         'range': 'int16', 'year': 'int16', 'make': 'category'})
 .drop(columns=['trany'])
 .memory_usage(deep=True)
 .sum()
)
# Out:
# C:\Users\Goncharuk.SM\AppData\Roaming\Python\Python310\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname EST identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# C:\Users\Goncharuk.SM\AppData\Roaming\Python\Python310\site-packages\dateutil\parser\_parser.py:1207: UnknownTimezoneWarning: tzname EDT identified but not understood.  Pass `tzinfos` argument in order to correctly return a timezone-aware datetime.  In a future version, this will raise an exception.
#   warnings.warn("tzname {tzname} identified but not understood.  "
# 7462959

# %%
# Python does not like EST/EDT
autos[cols].createdOn
# Out:
# 0        Tue Jan 01 00:00:00 EST 2013
# 1        Tue Jan 01 00:00:00 EST 2013
# 2        Tue Jan 01 00:00:00 EST 2013
# 3        Tue Jan 01 00:00:00 EST 2013
# 4        Tue Jan 01 00:00:00 EST 2013
# 5        Tue Jan 01 00:00:00 EST 2013
# 6        Tue Jan 01 00:00:00 EST 2013
# 7        Tue Jan 01 00:00:00 EST 2013
# 8        Tue Jan 01 00:00:00 EST 2013
# 9        Tue Jan 01 00:00:00 EST 2013
#                      ...
# 41134    Tue Jan 01 00:00:00 EST 2013
# 41135    Tue Jan 01 00:00:00 EST 2013
# 41136    Tue Jan 01 00:00:00 EST 2013
# 41137    Tue Jan 01 00:00:00 EST 2013
# 41138    Tue Jan 01 00:00:00 EST 2013
# 41139    Tue Jan 01 00:00:00 EST 2013
# 41140    Tue Jan 01 00:00:00 EST 2013
# 41141    Tue Jan 01 00:00:00 EST 2013
# 41142    Tue Jan 01 00:00:00 EST 2013
# 41143    Tue Jan 01 00:00:00 EST 2013
# Name: createdOn, Length: 41144, dtype: object

# %%
(autos
 [cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0).astype('float16'),\
         drive=autos.drive.fillna('Other').astype('category'),
         automatic=autos.trany.str.contains('Auto'),
         speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'),
         createdOn=pd.to_datetime(autos.createdOn.replace({'EST': '-07:00', 'EDT': '-06:00'}, regex=True)))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
         'range': 'int16', 'year': 'int16', 'make': 'category'})
 .drop(columns=['trany'])
 .eng_dscr
 .value_counts(dropna=False)
)
# Out:
# NaN                                 16153
# (FFS)                                8827
# SIDI                                 5526
# (FFS) CA model                        926
# (FFS)      (MPFI)                     734
# FFV                                   701
# (FFS,TRBO)                            666
# (350 V8) (FFS)                        411
# (GUZZLER)  (FFS)                      366
# SOHC                                  354
#                                     ...
# B234L/R4 (FFS,TRBO)                     1
# GUZZLER V8 FFS,TURBO                    1
# 4.6M FFS MPFI                           1
# CNG FFS                                 1
# POLICE FFS MPFI                         1
# B308E5 FFS,TURBO                        1
# 5.4E-R FFS MPFI                         1
# V-6 FFS                                 1
# (GUZZLER)  (FFS)      (S-CHARGE)        1
# R-ENG (FFS,TRBO)                        1
# Name: eng_dscr, Length: 558, dtype: int64

# %%
# Add ffs (Feedback fuel system), drop eng_descr
(autos
 [cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0).astype('float16'),\
         drive=autos.drive.fillna('Other').astype('category'),
         automatic=autos.trany.str.contains('Auto'),
         speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'),
         createdOn=pd.to_datetime(autos.createdOn.replace({'EST': '-07:00', 'EDT': '-06:00'}, regex=True)),
         ffs=autos.eng_dscr.str.contains('FFS'))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
         'range': 'int16', 'year': 'int16', 'make': 'category'})
 .drop(columns=['trany', 'eng_dscr'])
 .memory_usage(deep=True)
 .sum()
)
# Out:
# 8676214

# %%
# a glorious function --> add it to the cell next to original data in the begining of the notebook
def tweak_autos(autos):
    cols = ['city08', 'comb08', 'highway08', 'cylinders', 'displ', 'drive', 'eng_dscr', 
        'fuelCost08', 'make', 'model', 'trany', 'range', 'createdOn', 'year']
    return (autos
 [cols]
 .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
         displ=autos.displ.fillna(0).astype('float16'),\
         drive=autos.drive.fillna('Other').astype('category'),
         automatic=autos.trany.str.contains('Auto'),
         speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'),
         createdOn=pd.to_datetime(autos.createdOn.replace({'EST': '-07:00', 'EDT': '-06:00'}, regex=True)),
         ffs=autos.eng_dscr.str.contains('FFS'))
 .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
         'range': 'int16', 'year': 'int16', 'make': 'category'})
 .drop(columns=['trany', 'eng_dscr'])
)

tweak_autos(autos)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# 5          21      22         24          4  1.799805
# 6          22      25         29          4  1.799805
# 7          23      24         26          4  1.599609
# 8          23      26         31          4  1.599609
# 9          23      25         30          4  1.799805
# ...       ...     ...        ...        ...       ...
# 41134      18      20         24          4  2.099609
# 41135      23      26         33          4  1.900391
# 41136      21      24         30          4  1.900391
# 41137      24      28         33          4  1.900391
# 41138      21      25         32          4  1.900391
# 41139      19      22         26          4  2.199219
# 41140      20      23         28          4  2.199219
# 41141      18      21         24          4  2.199219
# 41142      18      21         24          4  2.199219
# 41143      16      18         21          4  2.199219
#
#                             drive  fuelCost08        make  \
# 0                Rear-Wheel Drive        2000  Alfa Romeo
# 1                Rear-Wheel Drive        3850     Ferrari
# 2               Front-Wheel Drive        1550       Dodge
# 3                Rear-Wheel Drive        3850       Dodge
# 4      4-Wheel or All-Wheel Drive        2700      Subaru
# 5               Front-Wheel Drive        1900      Subaru
# 6               Front-Wheel Drive        1700      Subaru
# 7               Front-Wheel Drive        1750      Toyota
# 8               Front-Wheel Drive        1600      Toyota
# 9               Front-Wheel Drive        1700      Toyota
# ...                           ...         ...         ...
# 41134           Front-Wheel Drive        2100        Saab
# 41135           Front-Wheel Drive        1600      Saturn
# 41136           Front-Wheel Drive        1750      Saturn
# 41137           Front-Wheel Drive        1500      Saturn
# 41138           Front-Wheel Drive        1700      Saturn
# 41139           Front-Wheel Drive        1900      Subaru
# 41140           Front-Wheel Drive        1850      Subaru
# 41141  4-Wheel or All-Wheel Drive        2000      Subaru
# 41142  4-Wheel or All-Wheel Drive        2000      Subaru
# 41143  4-Wheel or All-Wheel Drive        2900      Subaru
#
#                      model  range                  createdOn  year automatic  \
# 0       Spider Veloce 2000      0  2013-01-01 00:00:00-07:00  1985     False
# 1               Testarossa      0  2013-01-01 00:00:00-07:00  1985     False
# 2                  Charger      0  2013-01-01 00:00:00-07:00  1985     False
# 3      B150/B250 Wagon 2WD      0  2013-01-01 00:00:00-07:00  1985      True
# 4         Legacy AWD Turbo      0  2013-01-01 00:00:00-07:00  1993     False
# 5                   Loyale      0  2013-01-01 00:00:00-07:00  1993      True
# 6                   Loyale      0  2013-01-01 00:00:00-07:00  1993     False
# 7                  Corolla      0  2013-01-01 00:00:00-07:00  1993      True
# 8                  Corolla      0  2013-01-01 00:00:00-07:00  1993     False
# 9                  Corolla      0  2013-01-01 00:00:00-07:00  1993      True
# ...                    ...    ...                        ...   ...       ...
# 41134                  900      0  2013-01-01 00:00:00-07:00  1993     False
# 41135                   SL      0  2013-01-01 00:00:00-07:00  1993      True
# 41136                   SL      0  2013-01-01 00:00:00-07:00  1993      True
# 41137                   SL      0  2013-01-01 00:00:00-07:00  1993     False
# 41138                   SL      0  2013-01-01 00:00:00-07:00  1993     False
# 41139               Legacy      0  2013-01-01 00:00:00-07:00  1993      True
# 41140               Legacy      0  2013-01-01 00:00:00-07:00  1993     False
# 41141           Legacy AWD      0  2013-01-01 00:00:00-07:00  1993      True
# 41142           Legacy AWD      0  2013-01-01 00:00:00-07:00  1993     False
# 41143     Legacy AWD Turbo      0  2013-01-01 00:00:00-07:00  1993      True
#
#        speeds    ffs
# 0           5   True
# 1           5  False
# 2           5   True
# 3           3    NaN
# 4           5   True
# 5           3   True
# 6           5   True
# 7           3   True
# 8           5   True
# 9           4   True
# ...       ...    ...
# 41134       5   True
# 41135       4   True
# 41136       4   True
# 41137       5   True
# 41138       5   True
# 41139       4   True
# 41140       5   True
# 41141       4   True
# 41142       5   True
# 41143       4   True
#
# [41144 rows x 15 columns]

# %% [markdown]
# # Chain
#
# Chaining is also called "flow" programming. Rather than making intermediate veriables, just leverage the fact that most operations
# return a new object and work on that.
#
# The chain should read like a recepie of ordered steps.
#
# (BTW, this is acrually what we did above)
#
# Hint: Leverage .pipe if you can't find a way to chain

# %%
# Easy to debug
# - assing to var (df3)
# - comment out
# - pipe to display

from IPython.display import display

def get_var(df, var_name):
    globals()[var_name] = df
    return df

def tweak_autos(autos):
    return (autos
     [cols]
      # crate var
     .pipe(get_var, 'df3')
     .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
             displ=autos.displ.fillna(0).astype('float16'),\
             drive=autos.drive.fillna('Other').astype('category'),
             automatic=autos.trany.str.contains('Auto'),
             speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'),
             createdOn=pd.to_datetime(autos.createdOn.replace({'EST': '-07:00', 'EDT': '-06:00'}, regex=True)),
             ffs=autos.eng_dscr.str.contains('FFS'))
     # debug pipe
     .pipe(lambda df: display(df) or df)
     .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
             'range': 'int16', 'year': 'int16', 'make': 'category'})
     .drop(columns=['trany', 'eng_dscr'])
    )

tweak_autos(autos)
# Out:
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# 5          21      22         24          4  1.799805
# 6          22      25         29          4  1.799805
# 7          23      24         26          4  1.599609
# 8          23      26         31          4  1.599609
# 9          23      25         30          4  1.799805
# ...       ...     ...        ...        ...       ...
# 41134      18      20         24          4  2.099609
# 41135      23      26         33          4  1.900391
# 41136      21      24         30          4  1.900391
# 41137      24      28         33          4  1.900391
# 41138      21      25         32          4  1.900391
# 41139      19      22         26          4  2.199219
# 41140      20      23         28          4  2.199219
# 41141      18      21         24          4  2.199219
# 41142      18      21         24          4  2.199219
# 41143      16      18         21          4  2.199219
#
#                             drive          eng_dscr  fuelCost08        make  \
# 0                Rear-Wheel Drive             (FFS)        2000  Alfa Romeo
# 1                Rear-Wheel Drive         (GUZZLER)        3850     Ferrari
# 2               Front-Wheel Drive             (FFS)        1550       Dodge
# 3                Rear-Wheel Drive               NaN        3850       Dodge
# 4      4-Wheel or All-Wheel Drive        (FFS,TRBO)        2700      Subaru
# 5               Front-Wheel Drive             (FFS)        1900      Subaru
# 6               Front-Wheel Drive             (FFS)        1700      Subaru
# 7               Front-Wheel Drive             (FFS)        1750      Toyota
# 8               Front-Wheel Drive             (FFS)        1600      Toyota
# 9               Front-Wheel Drive             (FFS)        1700      Toyota
# ...                           ...               ...         ...         ...
# 41134           Front-Wheel Drive             (FFS)        2100        Saab
# 41135           Front-Wheel Drive  (TBI)      (FFS)        1600      Saturn
# 41136           Front-Wheel Drive  (MFI)      (FFS)        1750      Saturn
# 41137           Front-Wheel Drive  (TBI)      (FFS)        1500      Saturn
# 41138           Front-Wheel Drive  (MFI)      (FFS)        1700      Saturn
# 41139           Front-Wheel Drive             (FFS)        1900      Subaru
# 41140           Front-Wheel Drive             (FFS)        1850      Subaru
# 41141  4-Wheel or All-Wheel Drive             (FFS)        2000      Subaru
# 41142  4-Wheel or All-Wheel Drive             (FFS)        2000      Subaru
# 41143  4-Wheel or All-Wheel Drive        (FFS,TRBO)        2900      Subaru
#
#                      model            trany  range                  createdOn  \
# 0       Spider Veloce 2000     Manual 5-spd      0  2013-01-01 00:00:00-07:00
# 1               Testarossa     Manual 5-spd      0  2013-01-01 00:00:00-07:00
# 2                  Charger     Manual 5-spd      0  2013-01-01 00:00:00-07:00
# 3      B150/B250 Wagon 2WD  Automatic 3-spd      0  2013-01-01 00:00:00-07:00
# 4         Legacy AWD Turbo     Manual 5-spd      0  2013-01-01 00:00:00-07:00
# 5                   Loyale  Automatic 3-spd      0  2013-01-01 00:00:00-07:00
# 6                   Loyale     Manual 5-spd      0  2013-01-01 00:00:00-07:00
# 7                  Corolla  Automatic 3-spd      0  2013-01-01 00:00:00-07:00
# 8                  Corolla     Manual 5-spd      0  2013-01-01 00:00:00-07:00
# 9                  Corolla  Automatic 4-spd      0  2013-01-01 00:00:00-07:00
# ...                    ...              ...    ...                        ...
# 41134                  900     Manual 5-spd      0  2013-01-01 00:00:00-07:00
# 41135                   SL  Automatic 4-spd      0  2013-01-01 00:00:00-07:00
# 41136                   SL  Automatic 4-spd      0  2013-01-01 00:00:00-07:00
# 41137                   SL     Manual 5-spd      0  2013-01-01 00:00:00-07:00
# 41138                   SL     Manual 5-spd      0  2013-01-01 00:00:00-07:00
# 41139               Legacy  Automatic 4-spd      0  2013-01-01 00:00:00-07:00
# 41140               Legacy     Manual 5-spd      0  2013-01-01 00:00:00-07:00
# 41141           Legacy AWD  Automatic 4-spd      0  2013-01-01 00:00:00-07:00
# 41142           Legacy AWD     Manual 5-spd      0  2013-01-01 00:00:00-07:00
# 41143     Legacy AWD Turbo  Automatic 4-spd      0  2013-01-01 00:00:00-07:00
#
#        year automatic  speeds    ffs
# 0      1985     False       5   True
# 1      1985     False       5  False
# 2      1985     False       5   True
# 3      1985      True       3    NaN
# 4      1993     False       5   True
# 5      1993      True       3   True
# 6      1993     False       5   True
# 7      1993      True       3   True
# 8      1993     False       5   True
# 9      1993      True       4   True
# ...     ...       ...     ...    ...
# 41134  1993     False       5   True
# 41135  1993      True       4   True
# 41136  1993      True       4   True
# 41137  1993     False       5   True
# 41138  1993     False       5   True
# 41139  1993      True       4   True
# 41140  1993     False       5   True
# 41141  1993      True       4   True
# 41142  1993     False       5   True
# 41143  1993      True       4   True
#
# [41144 rows x 17 columns]
#        city08  comb08  highway08  cylinders     displ  \
# 0          19      21         25          4  2.000000
# 1           9      11         14         12  4.898438
# 2          23      27         33          4  2.199219
# 3          10      11         12          8  5.199219
# 4          17      19         23          4  2.199219
# 5          21      22         24          4  1.799805
# 6          22      25         29          4  1.799805
# 7          23      24         26          4  1.599609
# 8          23      26         31          4  1.599609
# 9          23      25         30          4  1.799805
# ...       ...     ...        ...        ...       ...
# 41134      18      20         24          4  2.099609
# 41135      23      26         33          4  1.900391
# 41136      21      24         30          4  1.900391
# 41137      24      28         33          4  1.900391
# 41138      21      25         32          4  1.900391
# 41139      19      22         26          4  2.199219
# 41140      20      23         28          4  2.199219
# 41141      18      21         24          4  2.199219
# 41142      18      21         24          4  2.199219
# 41143      16      18         21          4  2.199219
#
#                             drive  fuelCost08        make  \
# 0                Rear-Wheel Drive        2000  Alfa Romeo
# 1                Rear-Wheel Drive        3850     Ferrari
# 2               Front-Wheel Drive        1550       Dodge
# 3                Rear-Wheel Drive        3850       Dodge
# 4      4-Wheel or All-Wheel Drive        2700      Subaru
# 5               Front-Wheel Drive        1900      Subaru
# 6               Front-Wheel Drive        1700      Subaru
# 7               Front-Wheel Drive        1750      Toyota
# 8               Front-Wheel Drive        1600      Toyota
# 9               Front-Wheel Drive        1700      Toyota
# ...                           ...         ...         ...
# 41134           Front-Wheel Drive        2100        Saab
# 41135           Front-Wheel Drive        1600      Saturn
# 41136           Front-Wheel Drive        1750      Saturn
# 41137           Front-Wheel Drive        1500      Saturn
# 41138           Front-Wheel Drive        1700      Saturn
# 41139           Front-Wheel Drive        1900      Subaru
# 41140           Front-Wheel Drive        1850      Subaru
# 41141  4-Wheel or All-Wheel Drive        2000      Subaru
# 41142  4-Wheel or All-Wheel Drive        2000      Subaru
# 41143  4-Wheel or All-Wheel Drive        2900      Subaru
#
#                      model  range                  createdOn  year automatic  \
# 0       Spider Veloce 2000      0  2013-01-01 00:00:00-07:00  1985     False
# 1               Testarossa      0  2013-01-01 00:00:00-07:00  1985     False
# 2                  Charger      0  2013-01-01 00:00:00-07:00  1985     False
# 3      B150/B250 Wagon 2WD      0  2013-01-01 00:00:00-07:00  1985      True
# 4         Legacy AWD Turbo      0  2013-01-01 00:00:00-07:00  1993     False
# 5                   Loyale      0  2013-01-01 00:00:00-07:00  1993      True
# 6                   Loyale      0  2013-01-01 00:00:00-07:00  1993     False
# 7                  Corolla      0  2013-01-01 00:00:00-07:00  1993      True
# 8                  Corolla      0  2013-01-01 00:00:00-07:00  1993     False
# 9                  Corolla      0  2013-01-01 00:00:00-07:00  1993      True
# ...                    ...    ...                        ...   ...       ...
# 41134                  900      0  2013-01-01 00:00:00-07:00  1993     False
# 41135                   SL      0  2013-01-01 00:00:00-07:00  1993      True
# 41136                   SL      0  2013-01-01 00:00:00-07:00  1993      True
# 41137                   SL      0  2013-01-01 00:00:00-07:00  1993     False
# 41138                   SL      0  2013-01-01 00:00:00-07:00  1993     False
# 41139               Legacy      0  2013-01-01 00:00:00-07:00  1993      True
# 41140               Legacy      0  2013-01-01 00:00:00-07:00  1993     False
# 41141           Legacy AWD      0  2013-01-01 00:00:00-07:00  1993      True
# 41142           Legacy AWD      0  2013-01-01 00:00:00-07:00  1993     False
# 41143     Legacy AWD Turbo      0  2013-01-01 00:00:00-07:00  1993      True
#
#        speeds    ffs
# 0           5   True
# 1           5  False
# 2           5   True
# 3           3    NaN
# 4           5   True
# 5           3   True
# 6           5   True
# 7           3   True
# 8           5   True
# 9           4   True
# ...       ...    ...
# 41134       5   True
# 41135       4   True
# 41136       4   True
# 41137       5   True
# 41138       5   True
# 41139       4   True
# 41140       5   True
# 41141       4   True
# 41142       5   True
# 41143       4   True
#
# [41144 rows x 15 columns]

# %%
# inspect intermediate data frame
df3
# Out:
#        city08  comb08  highway08  cylinders  displ  \
# 0          19      21         25        4.0    2.0
# 1           9      11         14       12.0    4.9
# 2          23      27         33        4.0    2.2
# 3          10      11         12        8.0    5.2
# 4          17      19         23        4.0    2.2
# 5          21      22         24        4.0    1.8
# 6          22      25         29        4.0    1.8
# 7          23      24         26        4.0    1.6
# 8          23      26         31        4.0    1.6
# 9          23      25         30        4.0    1.8
# ...       ...     ...        ...        ...    ...
# 41134      18      20         24        4.0    2.1
# 41135      23      26         33        4.0    1.9
# 41136      21      24         30        4.0    1.9
# 41137      24      28         33        4.0    1.9
# 41138      21      25         32        4.0    1.9
# 41139      19      22         26        4.0    2.2
# 41140      20      23         28        4.0    2.2
# 41141      18      21         24        4.0    2.2
# 41142      18      21         24        4.0    2.2
# 41143      16      18         21        4.0    2.2
#
#                             drive          eng_dscr  fuelCost08        make  \
# 0                Rear-Wheel Drive             (FFS)        2000  Alfa Romeo
# 1                Rear-Wheel Drive         (GUZZLER)        3850     Ferrari
# 2               Front-Wheel Drive             (FFS)        1550       Dodge
# 3                Rear-Wheel Drive               NaN        3850       Dodge
# 4      4-Wheel or All-Wheel Drive        (FFS,TRBO)        2700      Subaru
# 5               Front-Wheel Drive             (FFS)        1900      Subaru
# 6               Front-Wheel Drive             (FFS)        1700      Subaru
# 7               Front-Wheel Drive             (FFS)        1750      Toyota
# 8               Front-Wheel Drive             (FFS)        1600      Toyota
# 9               Front-Wheel Drive             (FFS)        1700      Toyota
# ...                           ...               ...         ...         ...
# 41134           Front-Wheel Drive             (FFS)        2100        Saab
# 41135           Front-Wheel Drive  (TBI)      (FFS)        1600      Saturn
# 41136           Front-Wheel Drive  (MFI)      (FFS)        1750      Saturn
# 41137           Front-Wheel Drive  (TBI)      (FFS)        1500      Saturn
# 41138           Front-Wheel Drive  (MFI)      (FFS)        1700      Saturn
# 41139           Front-Wheel Drive             (FFS)        1900      Subaru
# 41140           Front-Wheel Drive             (FFS)        1850      Subaru
# 41141  4-Wheel or All-Wheel Drive             (FFS)        2000      Subaru
# 41142  4-Wheel or All-Wheel Drive             (FFS)        2000      Subaru
# 41143  4-Wheel or All-Wheel Drive        (FFS,TRBO)        2900      Subaru
#
#                      model            trany  range  \
# 0       Spider Veloce 2000     Manual 5-spd      0
# 1               Testarossa     Manual 5-spd      0
# 2                  Charger     Manual 5-spd      0
# 3      B150/B250 Wagon 2WD  Automatic 3-spd      0
# 4         Legacy AWD Turbo     Manual 5-spd      0
# 5                   Loyale  Automatic 3-spd      0
# 6                   Loyale     Manual 5-spd      0
# 7                  Corolla  Automatic 3-spd      0
# 8                  Corolla     Manual 5-spd      0
# 9                  Corolla  Automatic 4-spd      0
# ...                    ...              ...    ...
# 41134                  900     Manual 5-spd      0
# 41135                   SL  Automatic 4-spd      0
# 41136                   SL  Automatic 4-spd      0
# 41137                   SL     Manual 5-spd      0
# 41138                   SL     Manual 5-spd      0
# 41139               Legacy  Automatic 4-spd      0
# 41140               Legacy     Manual 5-spd      0
# 41141           Legacy AWD  Automatic 4-spd      0
# 41142           Legacy AWD     Manual 5-spd      0
# 41143     Legacy AWD Turbo  Automatic 4-spd      0
#
#                           createdOn  year
# 0      Tue Jan 01 00:00:00 EST 2013  1985
# 1      Tue Jan 01 00:00:00 EST 2013  1985
# 2      Tue Jan 01 00:00:00 EST 2013  1985
# 3      Tue Jan 01 00:00:00 EST 2013  1985
# 4      Tue Jan 01 00:00:00 EST 2013  1993
# 5      Tue Jan 01 00:00:00 EST 2013  1993
# 6      Tue Jan 01 00:00:00 EST 2013  1993
# 7      Tue Jan 01 00:00:00 EST 2013  1993
# 8      Tue Jan 01 00:00:00 EST 2013  1993
# 9      Tue Jan 01 00:00:00 EST 2013  1993
# ...                             ...   ...
# 41134  Tue Jan 01 00:00:00 EST 2013  1993
# 41135  Tue Jan 01 00:00:00 EST 2013  1993
# 41136  Tue Jan 01 00:00:00 EST 2013  1993
# 41137  Tue Jan 01 00:00:00 EST 2013  1993
# 41138  Tue Jan 01 00:00:00 EST 2013  1993
# 41139  Tue Jan 01 00:00:00 EST 2013  1993
# 41140  Tue Jan 01 00:00:00 EST 2013  1993
# 41141  Tue Jan 01 00:00:00 EST 2013  1993
# 41142  Tue Jan 01 00:00:00 EST 2013  1993
# 41143  Tue Jan 01 00:00:00 EST 2013  1993
#
# [41144 rows x 14 columns]

# %% [markdown]
# # Don't Apply (if you can)

# %%
def tweak_autos(autos):
    cols = ['city08', 'comb08', 'highway08', 'cylinders', 'displ', 'drive', 'eng_dscr', 
        'fuelCost08', 'make', 'model', 'trany', 'range', 'createdOn', 'year']
    return (autos
     [cols]
     .assign(cylinders=autos.cylinders.fillna(0).astype('int8'),
             displ=autos.displ.fillna(0).astype('float16'),\
             drive=autos.drive.fillna('Other').astype('category'),
             automatic=autos.trany.str.contains('Auto'),
             speeds=autos.trany.str.extract(r'(\d)+').fillna('20').astype('int8'),
             createdOn=pd.to_datetime(autos.createdOn.replace({'EST': '-07:00', 'EDT': '-06:00'}, regex=True)),
             ffs=autos.eng_dscr.str.contains('FFS'))
     .astype({'highway08': 'int8', 'city08': 'int16', 'comb08': 'int16', 'fuelCost08': 'int16',
             'range': 'int16', 'year': 'int16', 'make': 'category'})
     .drop(columns=['trany', 'eng_dscr'])
    )

autos2 = tweak_autos(autos)

# %%
# try to be more Euro-centric
def to_lper100km(val):
    return 235.215 / val
autos2.city08.apply(to_lper100km)
# Out:
# 0        12.379737
# 1        26.135000
# 2        10.226739
# 3        23.521500
# 4        13.836176
# 5        11.200714
# 6        10.691591
# 7        10.226739
# 8        10.226739
# 9        10.226739
#            ...
# 41134    13.067500
# 41135    10.226739
# 41136    11.200714
# 41137     9.800625
# 41138    11.200714
# 41139    12.379737
# 41140    11.760750
# 41141    13.067500
# 41142    13.067500
# 41143    14.700938
# Name: city08, Length: 41144, dtype: float64

# %%
# this gives the same result 
235.215 / autos.city08
# Out:
# 0        12.379737
# 1        26.135000
# 2        10.226739
# 3        23.521500
# 4        13.836176
# 5        11.200714
# 6        10.691591
# 7        10.226739
# 8        10.226739
# 9        10.226739
#            ...
# 41134    13.067500
# 41135    10.226739
# 41136    11.200714
# 41137     9.800625
# 41138    11.200714
# 41139    12.379737
# 41140    11.760750
# 41141    13.067500
# 41142    13.067500
# 41143    14.700938
# Name: city08, Length: 41144, dtype: float64

# %%
# %%timeit
autos2.city08.apply(to_lper100km)
# Out:
# 9.31 ms ± 193 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
235.215 / autos2.city08
# Out:
# 146 µs ± 2.81 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
9_310 / 146
# Out:
# 63.76712328767123

# %%
def is_american(val):
    return val in {'Chevrilet', 'Ford', 'Dodge', 'GMC', 'Tesla'}

# %%
# %%timeit
autos2.make.apply(is_american)
# Out:
# 1.03 ms ± 24.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
autos2.make.isin({'Chevrilet', 'Ford', 'Dodge', 'GMC', 'Tesla'})
# Out:
# 833 µs ± 7.45 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
def country(val):
    if val in {'Chevrilet', 'Ford', 'Dodge', 'GMC', 'Tesla'}:
        return 'US'
    return 'Other'

# %%
# %%timeit
(autos2
 .assign(country=autos2.make.apply(country))
)
# Out:
# 3.54 ms ± 237 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
values = {'Chevrilet', 'Ford', 'Dodge', 'GMC', 'Tesla'}
(autos2
 .assign(country='US')
 .assign(country=lambda df_:df_.country.where(df_.make.isin(values), 'Other'))
)
# Out:
# 11.6 ms ± 2.71 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit

(autos2
 .assign(country=np.select([autos2.make.isin({'Chevrilet', 'Ford', 'Dodge', 'GMC', 'Tesla'})],
                          ['US'], 'Other'))
)
# Out:
# 11.9 ms ± 1.5 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit

(autos2
 .assign(country=np.where(autos2.make.isin({'Chevrilet', 'Ford', 'Dodge', 'GMC', 'Tesla'}),
                         'US', 'Other'))
)
# Out:
# 9.01 ms ± 59.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# # Master Aggregation

# %% [markdown]
# Let's compare mileage by country by year

# %%
(autos2
 .groupby('year')
 .mean()
)
# Out:
#          city08     comb08  highway08  cylinders     displ   fuelCost08  \
# year
# 1984  17.982688  19.881874  23.075356   5.385438  3.164062  2313.543788
# 1985  17.878307  19.808348  23.042328   5.375661  3.164062  2334.509112
# 1986  17.665289  19.550413  22.699174   5.425620  3.183594  2354.049587
# 1987  17.310345  19.228549  22.445068   5.412189  3.173828  2403.648757
# 1988  17.333628  19.328319  22.702655   5.461947  3.195312  2387.035398
# 1989  17.143972  19.125759  22.465742   5.488291  3.208984  2433.434519
# 1990  17.033395  19.000928  22.337662   5.496289  3.216797  2436.178108
# 1991  16.848940  18.825972  22.253534   5.598940  3.267578  2490.856890
# 1992  16.805531  18.862623  22.439786   5.623550  3.275391  2494.736842
# 1993  16.998170  19.104300  22.780421   5.602928  3.248047  2454.620311
# 1994  16.918534  19.012220  22.725051   5.704684  3.333984  2461.507128
# 1995  16.569804  18.797311  22.671148   5.892451  3.472656  2497.828335
# 1996  17.289780  19.584735  23.569211   5.627426  3.234375  2375.032342
# 1997  17.135171  19.429134  23.451444   5.666667  3.226562  2405.511811
# 1998  17.113300  19.518473  23.546798   5.633005  3.201172  2382.635468
# 1999  17.272300  19.611502  23.552817   5.667840  3.189453  2392.194836
# 2000  17.221429  19.526190  23.414286   5.713095  3.201172  2429.702381
# 2001  17.275521  19.479693  23.328211   5.720088  3.193359  2448.463227
# 2002  16.893333  19.168205  23.030769   5.827692  3.263672  2479.794872
# 2003  16.780651  19.000958  22.836207   5.942529  3.357422  2525.574713
# 2004  16.740642  19.067736  23.064171   5.957219  3.394531  2512.566845
# 2005  16.851630  19.193825  23.297599   5.944254  3.400391  2518.610635
# 2006  16.626812  18.959239  23.048913   6.100543  3.548828  2539.175725
# 2007  16.605684  18.978686  23.083481   6.166075  3.628906  2535.923623
# 2008  16.900590  19.276327  23.455771   6.192923  3.638672  2536.436394
# 2009  17.334459  19.735642  24.017736   6.122466  3.625000  2427.027027
# 2010  18.105500  20.588819  24.947701   5.965735  3.501953  2351.082056
# 2011  18.669027  21.011504  25.169912   5.980531  3.521484  2333.982301
# 2012  19.362847  21.819444  26.105035   5.910590  3.460938  2289.973958
# 2013  20.661318  23.125000  27.504223   5.762669  3.328125  2210.768581
# 2014  21.033469  23.531429  27.978776   5.745306  3.289062  2198.040816
# 2015  21.445830  24.038971  28.586906   5.635230  3.205078  2148.869836
# 2016  22.591918  25.150555  29.606973   5.463550  3.054688  2091.204437
# 2017  22.761021  25.249033  29.554524   5.453210  3.025391  2096.558391
# 2018  22.564732  25.019345  29.273065   5.438988  2.992188  2103.980655
# 2019  23.318147  25.627942  29.664389   5.368261  2.964844  2093.545938
# 2020  22.679426  25.267943  29.617225   5.071770  2.644531  2023.444976
#
#          range    speeds
# year
# 1984  0.000000  3.928208
# 1985  0.000000  3.924750
# 1986  0.000000  3.984298
# 1987  0.000000  4.037690
# 1988  0.000000  4.129204
# 1989  0.000000  4.166522
# 1990  0.000000  4.238404
# 1991  0.000000  4.301237
# 1992  0.000000  4.318466
# 1993  0.000000  4.339433
# 1994  0.000000  4.332994
# 1995  0.000000  4.356774
# 1996  0.000000  4.364812
# 1997  0.000000  4.402887
# 1998  0.229064  4.419951
# 1999  0.570423  4.421362
# 2000  0.348810  4.508333
# 2001  0.261251  4.660812
# 2002  0.136410  4.757949
# 2003  0.090996  4.911877
# 2004  0.000000  4.976827
# 2005  0.000000  5.192110
# 2006  0.000000  5.315217
# 2007  0.000000  5.610124
# 2008  0.084246  5.773378
# 2009  0.000000  6.043074
# 2010  0.000000  6.271416
# 2011  0.259292  6.560177
# 2012  0.782118  6.706597
# 2013  1.255068  6.896959
# 2014  1.405714  6.985306
# 2015  2.208106  7.035853
# 2016  4.546751  7.080032
# 2017  4.336427  7.225058
# 2018  3.519345  7.017113
# 2019  5.565680  7.136674
# 2020  2.282297  7.746411

# %%
# Watch order of column fintering/aggregation
(autos2
 .groupby('year')
 [['comb08', 'speeds']]
 .mean()
)
# Out:
#          comb08    speeds
# year
# 1984  19.881874  3.928208
# 1985  19.808348  3.924750
# 1986  19.550413  3.984298
# 1987  19.228549  4.037690
# 1988  19.328319  4.129204
# 1989  19.125759  4.166522
# 1990  19.000928  4.238404
# 1991  18.825972  4.301237
# 1992  18.862623  4.318466
# 1993  19.104300  4.339433
# 1994  19.012220  4.332994
# 1995  18.797311  4.356774
# 1996  19.584735  4.364812
# 1997  19.429134  4.402887
# 1998  19.518473  4.419951
# 1999  19.611502  4.421362
# 2000  19.526190  4.508333
# 2001  19.479693  4.660812
# 2002  19.168205  4.757949
# 2003  19.000958  4.911877
# 2004  19.067736  4.976827
# 2005  19.193825  5.192110
# 2006  18.959239  5.315217
# 2007  18.978686  5.610124
# 2008  19.276327  5.773378
# 2009  19.735642  6.043074
# 2010  20.588819  6.271416
# 2011  21.011504  6.560177
# 2012  21.819444  6.706597
# 2013  23.125000  6.896959
# 2014  23.531429  6.985306
# 2015  24.038971  7.035853
# 2016  25.150555  7.080032
# 2017  25.249033  7.225058
# 2018  25.019345  7.017113
# 2019  25.627942  7.136674
# 2020  25.267943  7.746411

# %%
# %%timeit
# watch order of column fintering/aggregation
(autos2
 .groupby('year')
 [['comb08', 'speeds']]
 .mean()
)
# Out:
# 3.04 ms ± 185 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
# watch order of column fintering/aggregation
(autos2
 .groupby('year')
 .mean()
 [['comb08', 'speeds']]
)
# Out:
# 9.83 ms ± 367 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
(autos2
 .groupby('year')
 [['comb08', 'speeds']]
 .mean()
 .plot()
)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
(autos2
 .groupby('year')
 [['comb08', 'speeds']]
 # .median()
 # .quantile(.1)
   # .std()
   .var()
 .plot()
)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# Add country
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .mean()
)
# Out:
#                  city08     comb08  highway08  cylinders     displ  \
# year country
# 1984 Other    18.884866  20.918899  24.353367   5.143374  2.906250
#      US       15.845626  17.425386  20.048027   5.958834  3.779297
# 1985 Other    18.700429  20.765665  24.201717   5.145064  2.892578
#      US       16.091418  17.727612  20.522388   5.876866  3.753906
# 1986 Other    18.565584  20.577617  23.950662   5.117930  2.849609
#      US       15.691293  17.298153  19.955145   6.100264  3.916016
# 1987 Other    18.211670  20.257437  23.703661   5.106407  2.843750
#      US       15.198391  16.817694  19.495979   6.128686  3.947266
# 1988 Other    18.200999  20.320849  23.936330   5.136080  2.835938
#      US       15.221884  16.911854  19.699088   6.255319  4.070312
# ...                 ...        ...        ...        ...       ...
# 2016 Other    21.897770  24.447026  28.894981   5.505576  3.025391
#      US       26.607527  29.220430  33.725806   5.220430  3.218750
# 2017 Other    22.364130  24.859601  29.181159   5.456522  2.966797
#      US       25.079365  27.523810  31.735450   5.433862  3.369141
# 2018 Other    22.329279  24.813206  29.117289   5.411816  2.921875
#      US       23.968912  26.248705  30.202073   5.601036  3.414062
# 2019 Other    22.903454  25.271036  29.387954   5.357839  2.906250
#      US       25.808511  27.771277  31.324468   5.430851  3.314453
# 2020 Other    22.715000  25.330000  29.715000   5.120000  2.664062
#      US       21.888889  23.888889  27.444444   4.000000  2.234375
#
#                fuelCost08      range    speeds
# year country
# 1984 Other    2173.316437   0.000000  3.958726
#      US       2645.711835   0.000000  3.855918
# 1985 Other    2202.660944   0.000000  3.949356
#      US       2621.082090   0.000000  3.871269
# 1986 Other    2221.058965   0.000000  4.039711
#      US       2645.646438   0.000000  3.862797
# 1987 Other    2271.624714   0.000000  4.110984
#      US       2713.002681   0.000000  3.865952
# 1988 Other    2262.796504   0.000000  4.189763
#      US       2689.513678   0.000000  3.981763
# ...                   ...        ...       ...
# 2016 Other    2113.708178   1.009294  7.258364
#      US       1961.021505  25.010753  6.048387
# 2017 Other    2107.789855   1.361413  7.442935
#      US       2030.952381  21.714286  5.952381
# 2018 Other    2110.556038   1.255430  7.370982
#      US       2064.766839  17.020725  4.906736
# 2019 Other    2098.494243   2.573074  7.507529
#      US       2063.829787  23.537234  4.909574
# 2020 Other    2035.000000   2.385000  7.845000
#      US       1766.666667   0.000000  5.555556
#
# [74 rows x 8 columns]

# %%
# Can go deeper and apply multiple aggregations
def second_to_last(ser):
    return ser.iloc[-2]

(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .agg(['min', 'mean', second_to_last])
)
# Out:
#              city08                           comb08             \
#                 min       mean second_to_last    min       mean
# year country
# 1984 Other        7  18.884866             15      8  20.918899
#      US           8  15.845626             15      9  17.425386
# 1985 Other        7  18.700429             16      8  20.765665
#      US           8  16.091418             14     10  17.727612
# 1986 Other        6  18.565584             16      7  20.577617
#      US           9  15.691293             16     10  17.298153
# 1987 Other        6  18.211670             12      7  20.257437
#      US           8  15.198391             12      9  16.817694
# 1988 Other        6  18.200999             12      7  20.320849
#      US           8  15.221884             14      9  16.911854
# ...             ...        ...            ...    ...        ...
# 2016 Other       10  21.897770             28     12  24.447026
#      US          11  26.607527             91     12  29.220430
# 2017 Other       10  22.364130             21     11  24.859601
#      US          11  25.079365            131     12  27.523810
# 2018 Other        9  22.329279             11     11  24.813206
#      US          11  23.968912            120     14  26.248705
# 2019 Other        9  22.903454             19     11  25.271036
#      US          11  25.808511            104     14  27.771277
# 2020 Other       13  22.715000             17     15  25.330000
#      US          20  21.888889             21     22  23.888889
#
#                             highway08                           cylinders  \
#              second_to_last       min       mean second_to_last       min
# year country
# 1984 Other               17         9  24.353367             19         2
#      US                  17        10  20.048027             19         4
# 1985 Other               17         9  24.201717             19         0
#      US                  15        10  20.522388             17         4
# 1986 Other               17         9  23.950662             19         0
#      US                  17        11  19.955145             19         4
# 1987 Other               12         9  23.703661             12         2
#      US                  13        10  19.495979             14         4
# 1988 Other               12        10  23.936330             12         2
#      US                  14        10  19.699088             15         4
# ...                     ...       ...        ...            ...       ...
# 2016 Other               30        13  28.894981             32         0
#      US                  93        16  33.725806             94         0
# 2017 Other               24        11  29.181159             28         0
#      US                 126        15  31.735450            120         0
# 2018 Other               12        11  29.117289             15         0
#      US                 116        15  30.202073            112         0
# 2019 Other               22        14  29.387954             27         0
#      US                 104        15  31.324468            104         0
# 2020 Other               20        18  29.715000             24         0
#      US                  24        26  27.444444             28         4
#
#               ...          range automatic                          speeds  \
#               ... second_to_last       min      mean second_to_last    min
# year country  ...
# 1984 Other    ...              0     False  0.547429          False      3
#      US       ...              0     False  0.516351          False      3
# 1985 Other    ...              0     False  0.551073          False      3
#      US       ...              0     False  0.511194          False      3
# 1986 Other    ...              0     False  0.524669          False      3
#      US       ...              0     False  0.530343          False      3
# 1987 Other    ...              0     False  0.522883           True      3
#      US       ...              0     False  0.549598           True      3
# 1988 Other    ...              0     False  0.526841           True      3
#      US       ...              0     False  0.580547           True      3
# ...           ...            ...       ...       ...            ...    ...
# 2016 Other    ...              0     False  0.834572           True      1
#      US       ...            200     False  0.876344           True      1
# 2017 Other    ...              0     False  0.845109           True      0
#      US       ...            310     False  0.883598           True      0
# 2018 Other    ...              0     False  0.859253           True      0
#      US       ...            310     False  0.917098           True      0
# 2019 Other    ...              0     False  0.879539           True      0
#      US       ...            345     False  0.936170           True      0
# 2020 Other    ...              0     False  0.865000           True      0
#      US       ...              0      True  1.000000           True      0
#
#                                          ffs
#                   mean second_to_last    min      mean second_to_last
# year country
# 1984 Other    3.958726              4  False  0.676656            NaN
#      US       3.855918              4  False  0.714617            NaN
# 1985 Other    3.949356              4  False  0.872047            NaN
#      US       3.871269              4  False  0.876574            NaN
# 1986 Other    4.039711              4  False  0.890181            NaN
#      US       3.862797              4  False  0.832776            NaN
# 1987 Other    4.110984              4  False  0.940000           True
#      US       3.865952              4  False  0.913580           True
# 1988 Other    4.189763              4  False  0.976010           True
#      US       3.981763              4  False  0.951923           True
# ...                ...            ...    ...       ...            ...
# 2016 Other    7.258364              7  False  0.000000          False
#      US       6.048387              1  False  0.000000            NaN
# 2017 Other    7.442935              7  False  0.000000          False
#      US       5.952381              1  False  0.000000            NaN
# 2018 Other    7.370982              0  False  0.000000            NaN
#      US       4.906736              1  False  0.000000            NaN
# 2019 Other    7.507529              8  False  0.000000            NaN
#      US       4.909574              1  False  0.000000            NaN
# 2020 Other    7.845000              0  False  0.000000          False
#      US       5.555556              0  False  0.000000          False
#
# [74 rows x 30 columns]

# %%
# Back to a simplier example, adding plots
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .mean()
 .plot()
)
# Out:
# <AxesSubplot:xlabel='year,country'>

# %%
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .mean()
 .unstack()
)
# Out:
#             city08                comb08             highway08             \
# country      Other         US      Other         US      Other         US
# year
# 1984     18.884866  15.845626  20.918899  17.425386  24.353367  20.048027
# 1985     18.700429  16.091418  20.765665  17.727612  24.201717  20.522388
# 1986     18.565584  15.691293  20.577617  17.298153  23.950662  19.955145
# 1987     18.211670  15.198391  20.257437  16.817694  23.703661  19.495979
# 1988     18.200999  15.221884  20.320849  16.911854  23.936330  19.699088
# 1989     18.029376  14.991071  20.127295  16.690476  23.686659  19.497024
# 1990     18.011719  14.609677  20.101562  16.274194  23.680990  19.009677
# 1991     17.656250  14.610000  19.719952  16.346667  23.335337  19.253333
# 1992     17.512635  14.779310  19.672684  16.541379  23.407942  19.665517
# 1993     17.686203  14.941606  19.876679  16.795620  23.715507  19.985401
# 1994     17.594046  14.864198  19.774019  16.695473  23.634641  19.958848
# 1995     17.204670  14.635983  19.543956  16.523013  23.608516  19.815900
# 1996     18.120482  14.776042  20.507745  16.791667  24.657487  20.276042
# 1997     17.784014  14.942529  20.158163  16.965517  24.294218  20.603448
# 1998     17.815336  14.520231  20.303599  16.618497  24.461659  20.167630
# 1999     17.782222  15.327684  20.207407  17.338983  24.311111  20.661017
# 2000     17.748494  15.232955  20.140060  17.210227  24.182229  20.517045
# 2001     17.797222  15.308901  20.113889  17.089005  24.137500  20.277487
# 2002     17.434278  14.783920  19.818299  16.633166  23.859536  19.798995
# 2003     17.246722  14.873171  19.557807  16.721951  23.545888  19.931707
# 2004     17.141928  14.879397  19.565547  16.758794  23.702059  20.105528
# 2005     17.207354  14.989305  19.639428  16.860963  23.886619  20.213904
# 2006     16.919700  15.017647  19.331906  16.911765  23.550321  20.294118
# 2007     16.861522  15.261111  19.302326  17.277778  23.545455  20.655556
# 2008     17.169139  15.357955  19.601385  17.409091  23.889219  20.965909
# 2009     17.589567  15.791667  20.057087  17.791667  24.420276  21.583333
# 2010     18.309129  16.751724  20.846473  18.875862  25.268672  22.813793
# 2011     19.062040  16.581006  21.454259  18.659218  25.679285  22.463687
# 2012     19.595092  18.057471  22.098160  20.252874  26.451943  24.155172
# 2013     20.770669  20.000000  23.265748  22.273810  27.667323  26.517857
# 2014     21.133459  20.372671  23.641917  22.801242  28.099624  27.180124
# 2015     21.251799  22.707602  23.839928  25.333333  28.386691  29.888889
# 2016     21.897770  26.607527  24.447026  29.220430  28.894981  33.725806
# 2017     22.364130  25.079365  24.859601  27.523810  29.181159  31.735450
# 2018     22.329279  23.968912  24.813206  26.248705  29.117289  30.202073
# 2019     22.903454  25.808511  25.271036  27.771277  29.387954  31.324468
# 2020     22.715000  21.888889  25.330000  23.888889  29.715000  27.444444
#
#         cylinders               displ             fuelCost08               \
# country     Other        US     Other        US        Other           US
# year
# 1984     5.143374  5.958834  2.906250  3.779297  2173.316437  2645.711835
# 1985     5.145064  5.876866  2.892578  3.753906  2202.660944  2621.082090
# 1986     5.117930  6.100264  2.849609  3.916016  2221.058965  2645.646438
# 1987     5.106407  6.128686  2.843750  3.947266  2271.624714  2713.002681
# 1988     5.136080  6.255319  2.835938  4.070312  2262.796504  2689.513678
# 1989     5.177479  6.244048  2.851562  4.082031  2307.343941  2740.029762
# 1990     5.134115  6.393548  2.824219  4.191406  2301.106771  2770.806452
# 1991     5.288462  6.460000  2.908203  4.261719  2391.165865  2767.333333
# 1992     5.367028  6.358621  2.970703  4.152344  2410.168472  2737.068966
# 1993     5.326007  6.430657  2.933594  4.187500  2377.228327  2685.948905
# 1994     5.426252  6.551440  3.009766  4.316406  2383.829499  2697.736626
# 1995     5.653846  6.619247  3.179688  4.359375  2421.153846  2731.380753
# 1996     5.318417  6.562500  2.914062  4.207031  2282.013769  2656.510417
# 1997     5.401361  6.563218  2.962891  4.117188  2347.704082  2600.862069
# 1998     5.358372  6.647399  2.927734  4.214844  2310.876369  2647.687861
# 1999     5.447407  6.508475  2.943359  4.125000  2323.407407  2654.519774
# 2000     5.501506  6.511364  2.964844  4.093750  2383.659639  2603.409091
# 2001     5.526389  6.450262  2.957031  4.082031  2399.513889  2632.984293
# 2002     5.644330  6.542714  3.046875  4.113281  2434.793814  2655.276382
# 2003     5.780691  6.604878  3.164062  4.156250  2501.311085  2624.878049
# 2004     5.820152  6.592965  3.224609  4.175781  2489.219935  2620.854271
# 2005     5.825332  6.566845  3.253906  4.164062  2497.088866  2631.283422
# 2006     6.007495  6.611765  3.427734  4.214844  2525.053533  2616.764706
# 2007     6.083510  6.600000  3.515625  4.226562  2535.200846  2539.722222
# 2008     6.109792  6.670455  3.525391  4.277344  2537.388724  2530.965909
# 2009     6.022638  6.726190  3.498047  4.390625  2423.818898  2446.428571
# 2010     5.898340  6.413793  3.404297  4.148438  2353.060166  2337.931034
# 2011     5.886435  6.480447  3.392578  4.207031  2322.923239  2392.737430
# 2012     5.839468  6.310345  3.347656  4.085938  2284.151329  2322.701149
# 2013     5.707677  6.095238  3.242188  3.843750  2210.088583  2214.880952
# 2014     5.722744  5.894410  3.232422  3.662109  2203.524436  2161.801242
# 2015     5.633993  5.643275  3.154297  3.533203  2162.275180  2061.695906
# 2016     5.505576  5.220430  3.025391  3.218750  2113.708178  1961.021505
# 2017     5.456522  5.433862  2.966797  3.369141  2107.789855  2030.952381
# 2018     5.411816  5.601036  2.921875  3.414062  2110.556038  2064.766839
# 2019     5.357839  5.430851  2.906250  3.314453  2098.494243  2063.829787
# 2020     5.120000  4.000000  2.664062  2.234375  2035.000000  1766.666667
#
#             range               speeds
# country     Other         US     Other        US
# year
# 1984     0.000000   0.000000  3.958726  3.855918
# 1985     0.000000   0.000000  3.949356  3.871269
# 1986     0.000000   0.000000  4.039711  3.862797
# 1987     0.000000   0.000000  4.110984  3.865952
# 1988     0.000000   0.000000  4.189763  3.981763
# 1989     0.000000   0.000000  4.236230  3.997024
# 1990     0.000000   0.000000  4.291667  4.106452
# 1991     0.000000   0.000000  4.331731  4.216667
# 1992     0.000000   0.000000  4.340554  4.255172
# 1993     0.000000   0.000000  4.362637  4.270073
# 1994     0.000000   0.000000  4.347767  4.288066
# 1995     0.000000   0.000000  4.381868  4.280335
# 1996     0.000000   0.000000  4.399312  4.260417
# 1997     0.000000   0.000000  4.440476  4.275862
# 1998     0.291080   0.000000  4.452269  4.300578
# 1999     0.223704   1.892655  4.484444  4.180791
# 2000     0.268072   0.653409  4.578313  4.244318
# 2001     0.168056   0.612565  4.711111  4.471204
# 2002     0.122423   0.190955  4.845361  4.417085
# 2003     0.113230   0.000000  5.045292  4.365854
# 2004     0.000000   0.000000  5.102925  4.391960
# 2005     0.000000   0.000000  5.239019  4.946524
# 2006     0.000000   0.000000  5.359743  5.070588
# 2007     0.000000   0.000000  5.670190  5.294444
# 2008     0.098912   0.000000  5.841741  5.380682
# 2009     0.000000   0.000000  6.094488  5.732143
# 2010     0.000000   0.000000  6.301867  6.068966
# 2011     0.308097   0.000000  6.643533  6.117318
# 2012     0.572597   1.959770  6.770961  6.344828
# 2013     0.785433   4.095238  6.993110  6.315476
# 2014     0.875000   4.913043  7.130639  6.024845
# 2015     0.659173  12.280702  7.151079  6.286550
# 2016     1.009294  25.010753  7.258364  6.048387
# 2017     1.361413  21.714286  7.442935  5.952381
# 2018     1.255430  17.020725  7.370982  4.906736
# 2019     2.573074  23.537234  7.507529  4.909574
# 2020     2.385000   0.000000  7.845000  5.555556

# %%
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .mean()
 .unstack()
 .city08
 .plot()
)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# smoothe it out a bit with rolling
(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .mean()
 .unstack()
 .city08
 .rolling(2)
 .mean()
 .plot()
)
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# example
def val_gt(df_, num):
    return df_[df_.gt(num)].dropna()

(autos2
 .assign(country=autos2.make.apply(country))
 .groupby(['year', 'country'])
 .count()
 .pipe(val_gt, 700)
)
# Out:
#               city08  comb08  highway08  cylinders   displ   drive  \
# year country
# 1984 Other    1381.0  1381.0     1381.0     1381.0  1381.0  1381.0
# 1985 Other    1165.0  1165.0     1165.0     1165.0  1165.0  1165.0
# 1986 Other     831.0   831.0      831.0      831.0   831.0   831.0
# 1987 Other     874.0   874.0      874.0      874.0   874.0   874.0
# 1988 Other     801.0   801.0      801.0      801.0   801.0   801.0
# 1989 Other     817.0   817.0      817.0      817.0   817.0   817.0
# 1990 Other     768.0   768.0      768.0      768.0   768.0   768.0
# 1991 Other     832.0   832.0      832.0      832.0   832.0   832.0
# 1992 Other     831.0   831.0      831.0      831.0   831.0   831.0
# 1993 Other     819.0   819.0      819.0      819.0   819.0   819.0
# 1994 Other     739.0   739.0      739.0      739.0   739.0   739.0
# 1995 Other     728.0   728.0      728.0      728.0   728.0   728.0
# 2015 Other    1112.0  1112.0     1112.0     1112.0  1112.0  1112.0
# 2016 Other    1076.0  1076.0     1076.0     1076.0  1076.0  1076.0
# 2017 Other    1104.0  1104.0     1104.0     1104.0  1104.0  1104.0
# 2018 Other    1151.0  1151.0     1151.0     1151.0  1151.0  1151.0
# 2019 Other    1129.0  1129.0     1129.0     1129.0  1129.0  1129.0
#
#               fuelCost08    make   model   range  createdOn  automatic  \
# year country
# 1984 Other        1381.0  1381.0  1381.0  1381.0     1381.0     1381.0
# 1985 Other        1165.0  1165.0  1165.0  1165.0     1165.0     1165.0
# 1986 Other         831.0   831.0   831.0   831.0      831.0      831.0
# 1987 Other         874.0   874.0   874.0   874.0      874.0      874.0
# 1988 Other         801.0   801.0   801.0   801.0      801.0      801.0
# 1989 Other         817.0   817.0   817.0   817.0      817.0      817.0
# 1990 Other         768.0   768.0   768.0   768.0      768.0      768.0
# 1991 Other         832.0   832.0   832.0   832.0      832.0      832.0
# 1992 Other         831.0   831.0   831.0   831.0      831.0      831.0
# 1993 Other         819.0   819.0   819.0   819.0      819.0      819.0
# 1994 Other         739.0   739.0   739.0   739.0      739.0      739.0
# 1995 Other         728.0   728.0   728.0   728.0      728.0      728.0
# 2015 Other        1112.0  1112.0  1112.0  1112.0     1112.0     1112.0
# 2016 Other        1076.0  1076.0  1076.0  1076.0     1076.0     1076.0
# 2017 Other        1104.0  1104.0  1104.0  1104.0     1104.0     1104.0
# 2018 Other        1151.0  1151.0  1151.0  1151.0     1151.0     1151.0
# 2019 Other        1129.0  1129.0  1129.0  1129.0     1129.0     1129.0
#
#               speeds     ffs
# year country
# 1984 Other    1381.0  1268.0
# 1985 Other    1165.0  1016.0
# 1986 Other     831.0   774.0
# 1987 Other     874.0   850.0
# 1988 Other     801.0   792.0
# 1989 Other     817.0   793.0
# 1990 Other     768.0   761.0
# 1991 Other     832.0   832.0
# 1992 Other     831.0   829.0
# 1993 Other     819.0   819.0
# 1994 Other     739.0   739.0
# 1995 Other     728.0   726.0
# 2015 Other    1112.0   701.0
# 2016 Other    1076.0   743.0
# 2017 Other    1104.0   828.0
# 2018 Other    1151.0   907.0
# 2019 Other    1129.0   933.0
